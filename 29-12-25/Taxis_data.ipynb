# %% [markdown]
# # Exploratory Data Analysis (EDA) on Taxis Dataset
#
# ## Objective
# - To understand the structure of the dataset
# - To identify patterns and trends in data
# - To check missing values and data types
# - To visualize relationships between variables
#
# ## Dataset
# - Dataset used: **Taxis dataset**
# - Source: Seaborn library
# - Contains information about taxi trips and fares
#
# ## Tools Used
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn

# %% [markdown]
# ## Importing Required Libraries
# - Import libraries required for data analysis and visualization
# - Pandas is used for data handling
# - NumPy is used for numerical operations
# - Matplotlib and Seaborn are used for visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset
# - Load the Taxis dataset using Seaborn
# - Store the dataset in a DataFrame
# - Display the first few rows to understand the data

# %%
df = sns.load_dataset("taxis")
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %% [markdown]
# ## Understanding the Dataset
# - Check the number of rows and columns
# - View column names
# - Understand data types and non-null values

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %% [markdown]
# ## Statistical Summary
# - Get summary statistics of numerical columns
# - Helps understand mean, minimum, maximum, and spread of data

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %% [markdown]
# ### Observation
# - Numerical features have varying ranges and distributions
# - Further analysis is required to understand patterns and relationships

# %% [markdown]
# ## Statistical Summary (Categorical Data)
# - Displays summary of categorical (object) columns
# - Shows count, unique values, most frequent value, and its frequency

# %%
df.describe(include='object')
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %% [markdown]
# ### Observation
# - Categorical features contain repeated values, as indicated by the frequency of the most common category

# %% [markdown]
# ## Checking Missing Values
# - Identify missing values in the dataset
# - Helps decide if data cleaning is required

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %% [markdown]
# ### Observation
# - Some columns contain missing values
# - Missing values need to be handled before further analysis or modeling

# %% [markdown]
# ## Missing Values Analysis
# - Calculate percentage of missing values for each column
# - Calculate overall percentage of rows containing missing values

# %%
(df.isna().sum() / df.shape[0]) * 100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
print(f'Number of Missing Values:\n{df.shape[0] - df.dropna().shape[0]}')

((df.shape[0] - df.dropna().shape[0]) / df.shape[0]) * 100
#Reason
# - This calculation helps determine the percentage of rows affected by missing values in the dataset
# Why this is important in EDA

# Shows how much data will be lost if we drop missing rows

# Helps decide:

# Drop rows ❌

# Fill missing values ✅

# Prevents unnecessary data loss
# Out:
# Number of Missing Values:
# 92
# 1.4301259132597544

# %% [markdown]
# ### Observation
# - Some columns contain missing values in small percentages
# - Only a limited number of rows have missing data
# - Only about 1.43% of the data is lost after removing missing values
# - Dropping missing records is acceptable and does not impact the overall dataset

# %% [markdown]
# ## Handling Missing Values
# - Remove rows containing missing values
# - Ensures clean data for further analysis

# %%
df = df.dropna()

# %% [markdown]
# ### Verification of Missing Values Removal
# - Check whether missing records still exist

# %%
print(f'Number of Missing Values:\n{df.shape[0] - df.dropna().shape[0]}')
# Out:
# Number of Missing Values:
# 0

# %% [markdown]
# ### Observation
# - No missing values remain in the dataset after deletion
# - Dataset is now complete

# %% [markdown]
# ## Understanding Categorical Variables
# - Identify categorical columns in the dataset
# - Analyze frequency of values in categorical features

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['color', 'payment', 'pickup_zone', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough'],
#       dtype='object')

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
# - Categorical variables have unequal value distributions
# - Some categories occur more frequently than others

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 743.1+ KB

# %% [markdown]
# ## Data Validation
# ### Checking Invalid Values
# - Identify records with zero or invalid values
# - Ensures reliability of analysis

# %%
df[['passengers', 'distance', 'fare', 'total']].describe()
# Out:
#         passengers     distance         fare        total
# count  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931    18.310263
# std       1.207948     3.719775    10.722249    12.950365
# min       0.000000     0.000000     1.000000     1.300000
# 25%       1.000000     0.990000     6.500000    10.800000
# 50%       1.000000     1.650000     9.500000    14.160000
# 75%       2.000000     3.200000    15.000000    20.300000
# max       6.000000    36.700000   150.000000   174.820000

# %% [markdown]
# ### Observation
# - Passenger count ranges from 0 to 6, indicating the presence of trips with zero passengers.
# - Trip distance has a minimum value of 0, suggesting some trips have zero recorded distance.
# - Fare values are always positive, with a minimum fare of 1.
# - Total trip amount varies widely, indicating differences in distance, fare, tips, and tolls.

# %%
df[df['distance'] == 0].shape
# Out:
# (32, 14)

# %% [markdown]
# ### Observation
# - 32 trips have zero recorded distance
# - Such records are likely data errors or incomplete trip records

# %%
df[df['fare'] == 0].shape
# Out:
# (0, 14)

# %% [markdown]
# ### Observation
# - No trips with zero fare are present in the dataset
# - Fare values are valid for all records

# %% [markdown]
# ### Removing Invalid Records
# - Remove trips with zero distance

# %%
# df = df[df['distance'] > 0]

# %% [markdown]
# ### Observation
# - Trips with zero distance are removed
# - Dataset now contains only valid taxi trips

# %% [markdown]
# ## Univariate Analysis
# ### Numerical Features
# - Analyze distribution of numerical variables after data cleaning

# %%
df[['passengers', 'distance', 'fare', 'tip', 'total']].describe()
# Out:
#         passengers     distance         fare          tip        total
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703    18.310263
# std       1.207948     3.719775    10.722249     2.361897    12.950365
# min       0.000000     0.000000     1.000000     0.000000     1.300000
# 25%       1.000000     0.990000     6.500000     0.000000    10.800000
# 50%       1.000000     1.650000     9.500000     1.750000    14.160000
# 75%       2.000000     3.200000    15.000000     2.820000    20.300000
# max       6.000000    36.700000   150.000000    23.190000   174.820000

# %% [markdown]
# ### Observation
# - Most taxi trips involve a small number of passengers, with a median of 1 passenger.
# - Trip distances are generally short, as indicated by a median distance of 1.65.
# - Fare values are mostly low to moderate, with 50% of fares below 9.5.
# - Tips vary widely, with many trips having zero tip and a few having high tip values.
# - Total trip cost shows high variability due to differences in fare, tips, and distance.

# %% [markdown]
# ### Distribution of Trip Distance
# - Visualize how trip distances are distributed

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['distance'], bins=30, kde=True)
plt.title("Trip Distance Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - Trip distances are highly right-skewed.
# - Majority of trips cover very short distances, mostly below 5 units.
# - Long-distance trips are rare but present, forming a long tail in the distribution.
# - A few extreme values indicate outliers in trip distance.

# %% [markdown]
# ### Distribution of Fare
# - Visualize fare distribution after removing invalid trips

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['fare'], bins=30, kde=True)
plt.title("Fare Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - Fare values are highly right-skewed.
# - Most fares are concentrated in the lower range, roughly below 20.
# - A small number of trips have very high fares, creating a long right tail.
# - Presence of outliers indicates variability in trip lengths and charges.

# %% [markdown]
# ### Payment Type Distribution
# - Analyze frequency of different payment methods

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='payment', data=df)
plt.title("Payment Type Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - Credit card payments are significantly more common than cash payments.
# - The distribution indicates a strong preference for digital payment methods.
# - Payment data is imbalanced, with one category dominating the others.

# %% [markdown]
# ## Target Variable Identification
# - The target variable in this analysis is **tip**.
# - Tip is a numerical feature representing the gratuity amount.
# - The relationship between tip and other features is analyzed to understand tipping behavior.

# %% [markdown]
# ## Tip Analysis with Taxi Color
# - Tip is analyzed with respect to taxi color.
# - Taxi color is a categorical feature with two categories: yellow and green.

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
# - Yellow taxis have a higher number of trips compared to green taxis.
# - This difference in frequency should be considered while interpreting tip patterns.

# %%
sns.barplot(x=df['color'], y=df['tip'], estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %% [markdown]
# ### Observation
# - The standard deviation of tips for green taxis is higher than that for yellow taxis.
# - This indicates greater variability in tips received by green taxis.
# - Some green taxi trips receive very high tips, while others receive very low or zero tips.

# %%
sns.barplot(x=df['color'], y=df['tip'], estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %% [markdown]
# ### Observation
# - Yellow taxis have a higher average tip compared to green taxis.
# - This suggests that, on average, yellow taxi drivers receive higher tips.

# %%
sns.histplot(x=df.tip, hue=df.color, palette=['yellow', 'green'], kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Observation
# - Tip distributions for both taxi colors are right-skewed.
# - A large number of trips have zero or low tip values.
# - Yellow taxis show relatively higher tip values compared to green taxis.

# %% [markdown]
# ## Hypothesis Testing: Tip vs Taxi Color
#
# ### Need for Hypothesis Testing
# - Visual analysis shows differences in tips between yellow and green taxis.
# - However, graphical analysis alone is not sufficient to make a conclusion.
# - Hypothesis testing is used to statistically verify whether taxi color affects tip amount.

# %% [markdown]
# ### Test Used
# - Independent T-Test
# - Used to compare the mean tip values of two independent groups:
#   - Yellow taxis
#   - Green taxis

# %% [markdown]
# ### Hypotheses
# - **Null Hypothesis (H₀):** Mean tip of yellow taxis = Mean tip of green taxis
# - **Alternative Hypothesis (H₁):** Mean tip of yellow taxis ≠ Mean tip of green taxis

# %%
yellow_tip  = df['tip'].loc[df['color']=='yellow']
green_tip = df['tip'].loc[df['color']=='green']

# %%
yellow_tip.shape
# Out:
# (5373,)

# %%
green_tip.shape
# Out:
# (968,)

# %%
from scipy import stats

t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)

print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
if p_val < 0.05:
    print("Reject null hypothesis: Tips differ by taxi color")
else:
    print("Fail to reject null hypothesis: No significant tip difference by taxi color")
# Out:
# Independent T-Test statistic: 17.05932566128597
# P-value: 7.791088119489453e-64
# Reject null hypothesis: Tips differ by taxi color

# %% [markdown]
# ### Conclusion
# - The p-value is less than 0.05.
# - Null hypothesis is rejected.
# - Taxi color has a statistically significant effect on tip amount.

# %% [markdown]
# ## Tip Analysis with Payment Method
# - Tip is the target variable (numerical feature).
# - Payment method is a categorical feature.
# - This section analyzes how tipping behavior varies across payment types.

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
# - Some payment methods are used more frequently than others.
# - This imbalance should be considered while interpreting tip patterns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18,5))

# 1️⃣ Standard Deviation of tip by payment
plt.subplot(1,3,1)
sns.barplot(x=df['payment'], y=df['tip'], estimator='std')
plt.title("Tip Variability (STD) by Payment")
plt.ylabel("Standard Deviation of Tip")

# 2️⃣ Mean tip by payment
plt.subplot(1,3,2)
sns.barplot(x=df['payment'], y=df['tip'], estimator='mean')
plt.title("Average Tip by Payment")
plt.ylabel("Mean Tip")

# 3️⃣ Distribution of tips by payment
plt.subplot(1,3,3)
sns.histplot(x=df['tip'], hue=df['payment'], kde=True)
plt.title("Tip Distribution by Payment")
plt.xlabel("Tip Amount")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation (Tip Variability)
# - Credit card payments show higher variability in tip amounts.
# - This indicates that tips paid through credit cards vary widely across trips.
# - Cash payments show lower variability, suggesting more consistent (often zero or low) tip amounts.

# %% [markdown]
# ### Observation (Average Tip)
# - Average tip amount is higher for credit card payments compared to cash payments.
# - This suggests that customers tend to tip more when paying by credit card.
# - Cash payments are associated with lower average tip values.

# %% [markdown]
# ### Observation (Tip Distribution)
# - Tip distribution for both payment methods is right-skewed.
# - A large number of trips have zero or very low tips, especially for cash payments.
# - Credit card payments show a wider spread of tip values, including higher tip amounts.

# %% [markdown]
# ### Overall Insight
# - Payment method influences tipping behavior, with credit card payments associated with higher and more variable tips compared to cash payments.

# %% [markdown]
# ## Hypothesis Testing: Tip vs Payment Method
#
# ### Objective
# - To determine whether payment method has a significant effect on tip amount.
#
# ### Hypotheses
# - **H₀:** Distribution of tips for cash payments is equal to distribution of tips for credit card payments.
# - **H₁:** Distribution of tips for cash payments is not equal to distribution of tips for credit card payments.
#
# ### Test Used
# - Independent T-Test (two independent groups, numerical target variable).
#
# ### Procedure
# - Tips are divided into two independent samples based on payment method.
# - Independent T-Test is applied to compare mean tip values.

# %%
card = df['tip'].loc[df['payment'] == 'credit card']
cash = df['tip'].loc[df['payment'] == 'cash']

# %%
card.shape
# Out:
# (4546,)

# %%
cash.shape
# Out:
# (1795,)

# %%
from scipy import stats
t_stat, p_val = stats.ttest_ind(card, cash)

print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Tips differ by payment type")
else:
    print("Fail to reject null hypothesis: No significant tip difference by payment type")
# Out:
# Independent T-Test statistic: 49.09538452722153
# P-value: 0.0
# Reject null hypothesis: Tips differ by payment type

# %% [markdown]
# ### Observation
# - The p-value obtained from the Independent T-Test is 0.0, which is less than the significance level of 0.05.
# - This indicates a statistically significant difference in tip amounts between cash and credit card payments.
#
# ### Conclusion
# - The null hypothesis is rejected.
# - Payment method has a significant effect on tip amount.
# - Tips differ significantly between cash and credit card payment types.

# %% [markdown]
# ## Relation between Pickup Borough and Target Variable (Tip)
#
# ### Objective
# - To analyze how the pickup borough (categorical feature) influences the target variable (tip).
#
# ### Preliminary Analysis
# - Examine data structure and understand borough categories.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 743.1+ KB

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %% [markdown]
# ### Univariate Analysis of Pickup Borough
# - Analyze frequency of trips across different pickup boroughs.

# %%
sns.countplot(x=df['pickup_borough'], palette='Set2')
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_25996\705742570.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'], palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %% [markdown]
# ### Observation
# - Manhattan has the highest number of pickup trips by a large margin.
# - Queens and Brooklyn have significantly fewer trips compared to Manhattan.
# - Bronx has the lowest number of pickup trips.
# - The dataset is highly imbalanced with respect to pickup borough.

# %% [markdown]
# ### Mean Tip by Pickup Borough
# - Analyze average tip amount across pickup boroughs.

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], estimator='mean', palette='Set1')
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_25996\3030712938.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], estimator='mean', palette='Set1')
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %% [markdown]
# ### Observation
# - Queens has the highest average tip among all pickup boroughs.
# - Manhattan shows a moderate average tip value.
# - Brooklyn has a lower average tip compared to Manhattan and Queens.
# - Bronx has the lowest average tip amount.

# %% [markdown]
# ### Tip Variability by Pickup Borough
# - Analyze variation in tips using standard deviation.

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], estimator='std', palette='Set3')
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_25996\1027424487.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], estimator='std', palette='Set3')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %% [markdown]
# ### Observation
# - Queens shows the highest variability in tip amounts.
# - Manhattan has moderate variability in tips.
# - Bronx shows very low variability, indicating consistently low tip values.
# - Brooklyn has moderate variability compared to Bronx and Manhattan.

# %% [markdown]
# ### Tip Distribution by Pickup Borough
# - Compare tip distributions across boroughs.

# %%
sns.histplot(x=df.tip, hue=df.pickup_borough, kde=True, bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Observation
# - Tip distributions are right-skewed for all pickup boroughs.
# - Manhattan has the widest distribution due to a large number of trips.
# - Queens shows higher tip values with a longer right tail.
# - Bronx has tips concentrated near zero with very few high-tip values.
# - Brooklyn shows moderate tip values with less spread than Manhattan.

# %% [markdown]
# ### Overall Insight
# - Pickup borough influences tipping behavior.
# - Although Manhattan has the highest number of trips, Queens shows higher average and more variable tips.
# - Bronx consistently shows low tip amounts across all analyses.

# %% [markdown]
# ## Hypothesis Testing: Tip vs Pickup Borough (ANOVA)

# %% [markdown]
# ### Objective
# - To determine whether the **mean tip amount differs across pickup boroughs**.
#
# ### Why ANOVA is Used
# - Tip is a numerical variable.
# - Pickup borough is a categorical variable with **more than two groups**:
#   - Manhattan
#   - Brooklyn
#   - Queens
#   - Bronx
# - ANOVA (Analysis of Variance) is used to compare **means across multiple independent groups**.

# %% [markdown]
# ### Hypotheses
# - **H₀:** Mean tip is the same across all pickup boroughs.
# - **H₁:** At least one pickup borough has a different mean tip.

# %% [markdown]
# ### Data Preparation
# - Tips are separated based on pickup borough to form independent samples.

# %%
mannhattan = df['tip'].loc[df['pickup_borough']=='Manhattan']
brooklyn = df['tip'].loc[df['pickup_borough']=='Brooklyn']  
queens = df['tip'].loc[df['pickup_borough']=='Queens']
bronx = df['tip'].loc[df['pickup_borough']=='Bronx']

# %% [markdown]
# ### Performing One-Way ANOVA

# %%
from scipy import stats

f_stat, p_val = stats.f_oneway(mannhattan, brooklyn, queens, bronx)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
# Out:
# ANOVA F-statistic: 91.57933831850565
# P-value: 5.155109332422435e-58

# %% [markdown]
# ### Decision Rule
# - Significance level (α) = 0.05
# - If *p-value < 0.05* → Reject H₀
# - If *p-value ≥ 0.05* → Fail to reject H₀

# %%
if p_val < 0.05:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# Reject null hypothesis:

# %% [markdown]
# ### Interpretation
# - ANOVA helps determine whether **pickup borough influences tip amount statistically**, beyond visual analysis.

# %% [markdown]
# ### Observation
# - The p-value obtained from the ANOVA test is extremely small (≈ 5.15 × 10⁻⁵⁸), which is far below the significance level of 0.05.
# - This indicates strong statistical evidence that mean tip values differ across pickup boroughs.
#
# ### Conclusion
# - The null hypothesis is rejected.
# - There is a statistically significant difference in mean tip amounts among the pickup boroughs.
# - Pickup borough has a significant effect on the tip amount.

# %% [markdown]
# ## Post-hoc Analysis: Tukey HSD Test (Pickup Borough vs Tip)

# %% [markdown]
# ### Why Tukey HSD Test is Used
# - ANOVA confirmed that mean tip amounts differ across pickup boroughs.
# - However, ANOVA does not indicate **which specific borough pairs differ**.
# - Tukey HSD is a post-hoc test used to identify **pairwise differences** between groups.

# %% [markdown]
# ### Hypotheses (for each pair of boroughs)
# - **H₀:** Mean tip of Borough A = Mean tip of Borough B
# - **H₁:** Mean tip of Borough A ≠ Mean tip of Borough B

# %% [markdown]
# ### Performing Tukey HSD Test

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Prepare data
tip = df['tip']
pickup_borough = df['pickup_borough']

# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=tip, groups=pickup_borough, alpha=0.05)

print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %% [markdown]
# ### Observation (Tukey HSD Test Results)
#
# - All borough pair comparisons show **reject = True**, indicating statistically significant differences in mean tip values.
# - Bronx has significantly lower mean tips compared to Brooklyn, Manhattan, and Queens.
# - Brooklyn has significantly lower mean tips than Manhattan and Queens.
# - Manhattan has significantly lower mean tips compared to Queens.
# - Queens consistently shows the **highest mean tip values** among all pickup boroughs.

# %% [markdown]
# ### Conclusion
# - The Tukey HSD post-hoc analysis confirms that **mean tip amounts differ significantly between every pair of pickup boroughs**.
# - Queens receives the highest tips, while Bronx receives the lowest.
# - This validates the ANOVA result and confirms that **pickup borough strongly influences tipping behavior**.

# %% [markdown]
# ## Relation between Dropoff Borough and Target Variable (Tip)
#
# ### Objective
# - To analyze whether the dropoff borough influences the target variable (tip).

# %% [markdown]
# ### Preliminary Analysis
# - Understand categories and frequency of dropoff boroughs.

# %%
df['dropoff_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Brooklyn', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
df['dropoff_borough'].value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %% [markdown]
# ### Univariate Analysis of Dropoff Borough
# - Analyze frequency of trips across dropoff boroughs.

# %%
sns.countplot(x=df['dropoff_borough'], palette='Set2')
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_25996\2410664910.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'], palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %% [markdown]
# ### Observation
# - Manhattan has the highest number of dropoff trips by a very large margin.
# - Queens and Brooklyn have significantly fewer dropoffs compared to Manhattan.
# - Bronx has very few dropoff trips.
# - Staten Island has the lowest number of dropoff trips in the dataset.
# - The data is highly imbalanced with respect to dropoff borough.

# %% [markdown]
# ### Mean Tip by Dropoff Borough
# - Analyze average tip values across dropoff boroughs.

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'], estimator='mean', palette='Set1')
df['tip'].groupby(df['dropoff_borough']).mean()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_25996\1842456448.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'], estimator='mean', palette='Set1')
# dropoff_borough
# Bronx             0.534706
# Brooklyn          1.921590
# Manhattan         1.964321
# Queens            2.422022
# Staten Island    14.165000
# Name: tip, dtype: float64

# %% [markdown]
# ### Observation
# - Staten Island shows an unusually high average tip compared to other boroughs.
# - Queens has a higher average tip than Manhattan and Brooklyn.
# - Manhattan and Brooklyn have similar moderate average tip values.
# - Bronx has the lowest average tip amount.

# %% [markdown]
# ### Tip Variability by Dropoff Borough
# - Analyze variability in tips using standard deviation.

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'], estimator='std', palette='Set3')
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_25996\2114155246.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'], estimator='std', palette='Set3')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %% [markdown]
# ### Observation
# - Staten Island shows very high variability in tip amounts.
# - Queens also shows high variability compared to other boroughs.
# - Manhattan and Brooklyn have moderate variability in tips.
# - Bronx shows low variability, indicating consistently low tip values.

# %% [markdown]
# ### Tip Distribution by Dropoff Borough
# - Compare tip distributions across dropoff boroughs.

# %%
sns.histplot(x=df['tip'], hue=df['dropoff_borough'], kde=True, bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Observation
# - Tip distributions are right-skewed across all dropoff boroughs.
# - Manhattan has the widest distribution due to a large number of trips.
# - Queens and Brooklyn show higher tip values compared to Bronx.
# - Staten Island shows sparse but very high tip values, likely due to low trip count.

# %% [markdown]
# ### Overall Insight
# - Dropoff borough influences tipping behavior.
# - Although Manhattan dominates in trip volume, higher average and more variable tips are observed for Queens and Staten Island.
# - Bronx consistently shows the lowest tip amounts across all analyses.

# %% [markdown]
# ### Objective
# - To check whether the mean tip amount differs across dropoff boroughs.
#
# ### Test Used
# - One-way ANOVA
# - Used because tip is numerical and dropoff_borough has more than two categories.
#
# ### Hypotheses
# - **H₀:** Mean tip is the same across all dropoff boroughs.
# - **H₁:** At least one dropoff borough has a different mean tip.

# %%
mannhattan = df['tip'].loc[df['dropoff_borough']=='Manhattan']
brooklyn = df['tip'].loc[df['dropoff_borough']=='Brooklyn']  
queens = df['tip'].loc[df['dropoff_borough']=='Queens']
bronx = df['tip'].loc[df['dropoff_borough']=='Bronx']
staten_island = df['tip'].loc[df['dropoff_borough']=='Staten Island']

from scipy import stats
f_stat, p_val = stats.f_oneway(mannhattan, brooklyn, queens, bronx, staten_island)

print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
# Out:
# ANOVA F-statistic: 31.424177966968287
# P-value: 5.87859571331583e-26

# %% [markdown]
# ### Decision Rule
# - If p-value < 0.05 → Reject H₀
# - Otherwise → Fail to reject H₀

# %% [markdown]
# ## Hypothesis Testing: Tip vs Dropoff Borough (ANOVA)

# %% [markdown]
# ### Purpose
# - ANOVA indicates whether a difference exists.
# - Tukey HSD identifies which specific borough pairs differ.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tip = df['tip']
dropoff_borough = df['dropoff_borough']

tukey_result = pairwise_tukeyhsd(endog=tip, groups=dropoff_borough, alpha=0.05)
print(tukey_result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %% [markdown]
# ### Key Statistical Insights
# - ANOVA p-value is extremely small (≈ 5.88 × 10⁻²⁶), indicating a significant difference in mean tip values across dropoff boroughs.
# - The null hypothesis is rejected, confirming that dropoff borough affects tip amount.
# - Tukey HSD shows Bronx has significantly lower tips compared to all other boroughs.
# - Staten Island has significantly higher tips compared to all other boroughs.
# - No significant difference is observed between Brooklyn and Manhattan.

# %% [markdown]
# ## Relation between Pickup Zone and Dropoff Zone with Target Variable (Tip)

# %% [markdown]
# ### Identify Pickup Zone Categories
# - Examine the unique pickup zones present in the dataset.

# %%
df.pickup_zone.unique()
# Out:
# array(['Lenox Hill West', 'Upper West Side South', 'Alphabet City',
#        'Hudson Sq', 'Midtown East', 'Times Sq/Theatre District',
#        'Battery Park City', 'East Harlem South', 'Lincoln Square East',
#        'LaGuardia Airport', 'Murray Hill', 'Lincoln Square West',
#        'Financial District North', 'Upper West Side North',
#        'East Chelsea', 'Midtown Center', 'Gramercy',
#        'Penn Station/Madison Sq West', 'Sutton Place/Turtle Bay North',
#        'West Chelsea/Hudson Yards', 'Clinton East', 'Clinton West',
#        'UN/Turtle Bay South', 'Midtown South', 'Midtown North',
#        'Garment District', 'Lenox Hill East', 'Flatiron',
#        'TriBeCa/Civic Center', 'Upper East Side North', 'West Village',
#        'Greenwich Village South', 'JFK Airport', 'East Village',
#        'Union Sq', 'Yorkville West', 'Central Park',
#        'Meatpacking/West Village West', 'Kips Bay', 'Morningside Heights',
#        'Astoria', 'East Tremont', 'Upper East Side South',
# ...

# %% [markdown]
# ### Frequency of Pickup Zones
# - Analyze how trips are distributed across pickup zones.

# %%
df.pickup_zone.value_counts()
# Out:
# pickup_zone
# Midtown Center                  227
# Penn Station/Madison Sq West    209
# Clinton East                    208
# Upper East Side South           208
# Midtown East                    196
#                                ...
# Ozone Park                        1
# Glendale                          1
# Woodlawn/Wakefield                1
# West Farms/Bronx River            1
# Hillcrest/Pomonok                 1
# Name: count, Length: 194, dtype: int64

# %% [markdown]
# ### Observation
# - A large number of pickup zones are present.
# - Most zones have very few trips, while a few zones dominate the dataset.

# %% [markdown]
# ### Univariate Analysis: Pickup Zone
# - Visualize trip frequency across pickup zones.

# %%
sns.countplot(data=df, x='pickup_zone')
# Out:
# <Axes: xlabel='pickup_zone', ylabel='count'>

# %% [markdown]
# ### Observation
# - Pickup zone distribution is highly imbalanced.
# - A few pickup zones have very high trip counts.
# - Most pickup zones have very low frequencies.
# - Due to a large number of categories, graphical interpretation is difficult.

# %% [markdown]
# ### Univariate Analysis: Dropoff Zone
# - Visualize trip frequency across dropoff zones.

# %%
sns.countplot(data=df, x='dropoff_zone')
# Out:
# <Axes: xlabel='dropoff_zone', ylabel='count'>

# %% [markdown]
# ### Observation
# - Dropoff zone distribution is also highly skewed.
# - Only a small number of zones dominate the dropoff counts.
# - Majority of dropoff zones have very few trips.
# - Visual analysis is challenging because of many zone categories.

# %% [markdown]
# ## Hypothesis Testing: Tip vs Pickup Zone (ANOVA)

# %% [markdown]
# ### Hypotheses
# - **H₀:** Mean tip is the same across all pickup zones.
# - **H₁:** At least one pickup zone has a different mean tip.

# %%
categories = [group['tip'].values for name, group in df.groupby('pickup_zone')]

from scipy import stats
f_stat, p_val = stats.f_oneway(*categories)

print(f'ANOVA statistic: {f_stat}')
print(f'P-Value: {p_val}')
# Out:
# ANOVA statistic: 7.563376210961916
# P-Value: 7.892434822136223e-169

# %% [markdown]
# ### Observation
# - The p-value is far below 0.05.
# - Null hypothesis is rejected.
# - Pickup zone has a significant effect on tip amount.

# %% [markdown]
# ## Hypothesis Testing: Tip vs Dropoff Zone (ANOVA)

# %% [markdown]
# ### Hypotheses
# - **H₀:** Mean tip is the same across all dropoff zones.
# - **H₁:** At least one dropoff zone has a different mean tip.

# %%
categories = [group['tip'].values for name, group in df.groupby('dropoff_zone')]

f_stat, p_val = stats.f_oneway(*categories)

print(f'ANOVA statistic: {f_stat}')
print(f'P-Value: {p_val}')
# Out:
# ANOVA statistic: 5.76903467327541
# P-Value: 1.3107168403745948e-120

# %% [markdown]
# ### Observation
# - The p-value is far below 0.05.
# - Null hypothesis is rejected.
# - Dropoff zone has a significant effect on tip amount.

# %% [markdown]
# ### Final Decision
# - Both **pickup_zone** and **dropoff_zone** features significantly influence the target variable **tip**.

# %% [markdown]
# ## Numerical Columns with Target Variable (Tip)

# %% [markdown]
# ### Dataset Overview
# - Inspect data types and numerical features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 743.1+ KB

# %% [markdown]
# ### Distribution of Target Variable (Tip)

# %%
sns.histplot(df['tip'], kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Observation
# - Tip values are right-skewed.
# - Most trips have low or zero tip values.
# - A small number of trips show high tip amounts.

# %% [markdown]
# ## Relation between Passengers and Tip

# %% [markdown]
# ### Distribution of Passenger Count

# %%
sns.histplot(data=df, x='passengers', kde=True)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %% [markdown]
# ### Observation
# - Majority of trips have one or two passengers.
# - Trips with higher passenger counts are rare.

# %% [markdown]
# ### Scatter Plot: Tip vs Passengers
# - Visualize relationship between passenger count and tip amount.

# %%
sns.scatterplot(x=df['tip'], y=df['passengers'])
plt.show()

# %% [markdown]
# ### Observation
# - No clear linear relationship is observed between passengers and tip.
# - Tip values vary widely for the same passenger count.

# %% [markdown]
# ## Spearman Correlation Test: Tip vs Passengers

# %% [markdown]
# ### Why Spearman Correlation?
# - Tip data is non-normally distributed.
# - Relationship appears non-linear.
# - Spearman correlation measures monotonic relationships using ranks.

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['passengers'])
print("Correlation :", r)
print("P-value :", p_val)
# Out:
# Correlation : 0.027509812818779178
# P-value : 0.028480753176042872

# %% [markdown]
# ### Hypotheses
# - **H₀:** No monotonic relationship between passengers and tip.
# - **H₁:** A monotonic relationship exists between passengers and tip.

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %% [markdown]
# ### Conclusion
# - Spearman correlation value indicates a weak relationship between passengers and tip.
# - Based on the p-value, passenger count does not significantly influence tip amount.

# %% [markdown]
# ## Relation between Fare and Target Variable (Tip)

# %% [markdown]
# ### Distribution of Fare
# - Analyze the distribution of fare values.

# %%
sns.histplot(data=df, x='fare', kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# ### Observation
# - Fare distribution is right-skewed.
# - Most trips have low to moderate fare values.
# - A few trips have very high fares, indicating outliers.

# %% [markdown]
# ### Relation between fair and tip features

# %% [markdown]
# ### Scatter Plot: Fare vs Tip
# - Visualize the relationship between fare amount and tip.

# %%
sns.scatterplot(x=df['tip'], y=df['fare'])
plt.show()

# %% [markdown]
# ### Observation
# - Tip amount generally increases as fare increases.
# - The relationship between fare and tip appears positive but not strictly linear.
# - High variability in tip values exists for similar fare amounts.

# %% [markdown]
# ## Correlation Analysis: Fare vs Tip (Spearman Correlation)

# %% [markdown]
# ### Hypotheses
# - **H₀:** Correlation between fare and tip is zero.
# - **H₁:** Correlation between fare and tip is not zero.

# %% [markdown]
# ### Why Spearman Correlation?
# - Fare and tip distributions are non-normal.
# - Presence of outliers and skewness.
# - Relationship is monotonic but not strictly linear.

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['fare'])
print("Correlation :", r)
print("P-value :", p_val)
# Out:
# Correlation : 0.310254279563729
# P-value : 1.5556730728881364e-141

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %% [markdown]
# ### Conclusion
# - Spearman correlation measures the strength of monotonic relationship between fare and tip.
# - Based on the p-value, the correlation between fare and tip is statistically significant.
# - Fare has a significant influence on tip amount.

# %% [markdown]
# ## Relation between Total Amount and Target Variable (Tip)

# %% [markdown]
# ### Distribution of Total Amount
# - Analyze the distribution of total trip amount.

# %%
sns.histplot(df['total'], kde=True)
plt.show()

# %% [markdown]
# ### Observation
# - Total amount distribution is right-skewed.
# - Most trips have low to moderate total amounts.
# - A few trips show very high total values, indicating outliers.

# %% [markdown]
# ### Scatter Plot: Total Amount vs Tip
# - Visualize the relationship between total amount and tip.

# %%
sns.scatterplot(x=df['tip'], y=df['total'])
plt.show()

# %% [markdown]
# ### Observation
# - Tip amount increases as total trip amount increases.
# - A positive monotonic relationship is observed.
# - Considerable variation in tip values exists for similar total amounts.

# %% [markdown]
# ## Correlation Analysis: Total Amount vs Tip (Spearman Correlation)

# %% [markdown]
# ### Hypotheses
# - **H₀:** Correlation between total amount and tip is zero.
# - **H₁:** Correlation between total amount and tip is not zero.

# %% [markdown]
# ### Why Spearman Correlation?
# - Total amount and tip are non-normally distributed.
# - Presence of skewness and outliers.
# - Relationship is monotonic but not strictly linear.

# %%
# Hypthesis for correlation 
# H0:correlation is zero
# H1: not zero

r, p_val = stats.spearmanr(df['tip'], df['total'])
print("Correlation :", r)
print("P-value :", p_val)

alpha = 0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation : 0.5028299699182296
# P-value : 0.0
# Reject null hypothesis

# %% [markdown]
# ### Conclusion
# - Spearman correlation value is **0.50**, indicating a **moderate positive relationship** between total amount and tip.
# - The p-value is **0.0**, which is less than the significance level of 0.05.
# - The null hypothesis is rejected.
# - Total trip amount has a **statistically significant influence** on tip amount.

# %% [markdown]
# ### Distribution of Tolls
# - Analyze the distribution of toll charges.

# %%
sns.histplot(df['tolls'], kde=True)
plt.show()

# %% [markdown]
# ### Observation
# - Tolls are highly right-skewed.
# - Majority of trips have zero toll charges.
# - Only a small number of trips include tolls, with a few high-value outliers.

# %% [markdown]
# ### Scatter Plot: Tolls vs Tip
# - Visualize the relationship between tolls and tip amount.

# %%
sns.scatterplot(x=df['tip'], y=df['tolls'])
plt.show()

# %% [markdown]
# ### Observation
# - No clear linear relationship between tolls and tip.
# - Tips vary widely even when toll charges are the same.
# - Many trips with zero tolls still receive tips.

# %% [markdown]
# ---

# %% [markdown]
# ## Correlation Analysis: Tolls vs Tip (Spearman Correlation)

# %% [markdown]
# ### Hypotheses
# - **H₀:** Correlation between tolls and tip is zero.
# - **H₁:** Correlation between tolls and tip is not zero.

# %% [markdown]
# ### Why Spearman Correlation?
# - Tolls contain many zero values.
# - Data is highly skewed with outliers.
# - Relationship is non-linear.

# %%
# Hypthesis for correlation 
# H0:correlation is zero
# H1: not zero

r, p_val = stats.spearmanr(df['tip'], df['tolls'])
print("Correlation :", r)
print("P-value :", p_val)

alpha = 0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation : 0.175380002891528
# P-value : 5.643276180955435e-45
# Reject null hypothesis

# %% [markdown]
# ### Conclusion
# - Spearman correlation indicates a weak relationship between tolls and tip.
# - Based on the p-value, the relationship is statistically significant.
# - Tolls have limited influence on tip amount compared to fare and total.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Spearman Correlation Matrix for Numerical Features

# %% [markdown]
# ### Purpose
# - Analyze monotonic relationships between numerical features and the target variable (tip).
# - Spearman correlation is used due to non-normal distributions and presence of outliers.

# %%
nm = df[['tip','passengers','fare','distance','total','tolls']]
nm.corr(method='spearman')
# Out:
#                  tip  passengers      fare  distance     total     tolls
# tip         1.000000    0.027510  0.310254  0.292651  0.502830  0.175380
# passengers  0.027510    1.000000 -0.000692  0.004688  0.020121 -0.005465
# fare        0.310254   -0.000692  1.000000  0.937097  0.946613  0.367724
# distance    0.292651    0.004688  0.937097  1.000000  0.883803  0.363687
# total       0.502830    0.020121  0.946613  0.883803  1.000000  0.377317
# tolls       0.175380   -0.005465  0.367724  0.363687  0.377317  1.000000

# %% [markdown]
# ### Correlation Heatmap
# - Visual representation of Spearman correlation values.

# %%
sns.heatmap(nm.corr(method='spearman'), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Observations (Spearman Correlation Heatmap)
#
# - Tip shows a **moderate positive correlation** with:
#   - Total (≈ 0.50)
#   - Fare (≈ 0.31)
#   - Distance (≈ 0.29)
#
# - Passenger count has **almost no correlation** with tip, fare, distance, or total.
#   - Indicates passenger count does not influence pricing or tipping.
#
# - Fare, distance, and total are **strongly correlated** with each other.
#   - Fare vs distance ≈ 0.94
#   - Fare vs total ≈ 0.95
#   - Distance vs total ≈ 0.88
#   - Indicates strong multicollinearity among monetary features.
#
# - Tolls show a **weak positive correlation** with:
#   - Total (≈ 0.38)
#   - Fare (≈ 0.37)
#   - Tip (≈ 0.18)
#
# - Monetary variables influence tip more than passenger-related features.

# %% [markdown]
# ### Key Insight
# - Tip amount is mainly influenced by **fare and total trip cost**, not by passenger count.
# - Strong multicollinearity exists among fare, distance, and total.

# %%
sns.heatmap(nm.corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Fare vs Distance
# - Analyze relationship between trip distance and fare

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='distance', y='fare', data=df)
plt.title("Fare vs Distance")
plt.show()

# %% [markdown]
# ### Observation
# - Fare increases as trip distance increases, showing a strong positive relationship.
# - Most trips are clustered at lower distances with correspondingly lower fares.
# - A few trips have very high fares at larger distances, indicating outliers.
# - The overall pattern suggests distance is a major factor influencing fare.

# %% [markdown]
# ### Fare vs Tip
# - Understand how tip varies with fare amount

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='fare', y='tip', data=df)
plt.title("Tip vs Fare")
plt.show()

# %% [markdown]
# ### Observation
# - Tip amount generally increases as fare increases, indicating a positive relationship.
# - Many trips have zero tip even at higher fare values.
# - Tip values show high variability for similar fare amounts.
# - A few high-fare trips receive unusually high tips, indicating outliers.

# %% [markdown]
# ### Distance vs Total Amount
# - Analyze effect of distance on total trip cost

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='distance', y='total', data=df)
plt.title("Total Amount vs Distance")
plt.show()

# %% [markdown]
# ### Observation
# - Total trip amount increases with increase in trip distance.
# - Most trips are concentrated at lower distances with lower total amounts.
# - A linear pattern is observed, suggesting distance strongly influences total cost.
# - A few long-distance trips result in very high total amounts.

# %% [markdown]
# ### Payment Type vs Fare
# - Compare fare distribution across payment methods

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='payment', y='fare', data=df)
plt.title("Fare Distribution by Payment Type")
plt.show()

# %% [markdown]
# ### Observation
# - Fare distributions for credit card and cash payments are similar in median value.
# - Credit card payments show a wider spread in fare values.
# - Both payment types contain outliers, with a few trips having very high fares.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ### Correlation Matrix
# - Measure strength and direction of relationship between numerical variables

# %%
corr = df[['passengers', 'distance', 'fare', 'tip', 'total']].corr()
corr
# Out:
#             passengers  distance      fare       tip     total
# passengers    1.000000  0.005481 -0.000912  0.017838  0.008380
# distance      0.005481  1.000000  0.947958  0.476980  0.929224
# fare         -0.000912  0.947958  1.000000  0.487101  0.972311
# tip           0.017838  0.476980  0.487101  1.000000  0.650677
# total         0.008380  0.929224  0.972311  0.650677  1.000000

# %% [markdown]
# ### Observation
# - Distance and fare have a very strong positive correlation (0.95), indicating fare increases with distance.
# - Fare and total amount show an extremely strong correlation (0.97), making fare a major contributor to total cost.
# - Distance is also strongly correlated with total amount (0.93), confirming its influence on overall trip cost.
# - Tip has a moderate positive correlation with fare (0.49) and total amount (0.65).
# - Passenger count shows almost no correlation with fare, distance, or total amount.

# %% [markdown]
# ### Correlation Heatmap
# - Visual representation of correlations between variables

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Conclusion
# - The taxis dataset was explored and cleaned by handling missing and invalid records.
# - Most taxi trips are short-distance with low to moderate fare values.
# - Distance is the strongest factor influencing fare and total trip cost.
# - Fare and total amount show a very strong positive correlation.
# - Tip amount generally increases with fare but shows high variability.
# - Passenger count has minimal impact on fare or total cost.
# - Overall, the dataset is well-structured and suitable for further analysis or modeling.
